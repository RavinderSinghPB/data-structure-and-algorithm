# %%
import numpy as np

# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mp

# %%
photo = mp.imread('photo.jpg')
pcv=cv2.imread('photo.jpg')

# %%
photo.shape
# Out:
# (288, 552, 3)

# %%
plt.imshow(photo)
#plt.imshow(pcv)

# %%
nphoto=photo.copy()
nphoto[10][200] = [0,255,0]
plt.imshow(nphoto)

# %%
nphoto[10][200]
# Out:
# array([  0, 255,   0], dtype=uint8)

# %%
cphoto = photo[: , 350:550,:]
plt.imshow(cphoto)

# %%
cp2=photo[25:140,:270]
plt.imshow(cp2)

# %%
bw=photo[:]
bw[:,:,]

# %%
a[:] = 250

# %%
a
# Out:
# array([[250, 250, 250, 250],
#        [250, 250, 250, 250],
#        [250, 250, 250, 250],
#        [250, 250, 250, 250]])

# %%
cv2.imshow('hi', cphoto)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
a
# Out:
# array([[250, 250, 250, 250],
#        [250, 250, 250, 250],
#        [250, 250, 250, 250],
#        [250, 250, 250, 250]])

# %%
b = np.array([30,30])

# %%
a
# Out:
# array([[250, 250, 250, 250],
#        [250, 250, 250, 250],
#        [250, 250, 250, 250],
#        [250, 250, 250, 250]])

# %%
b
# Out:
# array([30, 30])

# %%
a[1, 1:3] = b

# %%
a
# Out:
# array([[250, 250, 250, 250],
#        [250,  30,  30, 250],
#        [250, 250, 250, 250],
#        [250, 250, 250, 250]])

# %%
x=5

# %%
y=10

# %%
x = y

# %%
x
# Out:
# 10

# %%
photo
# Out:
# array([[[34, 18, 36],
#         [34, 18, 36],
#         [34, 18, 36],
#         ...,
#         [36, 17, 12],
#         [37, 18, 13],
#         [37, 18, 13]],
#
#        [[35, 19, 37],
#         [35, 19, 37],
#         [35, 19, 37],
#         ...,
#         [36, 17, 12],
#         [37, 18, 13],
#         [37, 18, 13]],
#
#        [[36, 20, 38],
#         [36, 20, 38],
#         [36, 20, 38],
#         ...,
#         [36, 17, 12],
#         [37, 18, 13],
#         [37, 18, 13]],
#
#        ...,
#
#        [[37, 17, 12],
#         [36, 17, 12],
#         [34, 16, 15],
#         ...,
#         [36, 18, 11],
#         [36, 18, 11],
#         [36, 18, 11]],
#
#        [[38, 18, 13],
#         [38, 18, 13],
#         [37, 18, 15],
#         ...,
#         [36, 18, 11],
#         [36, 18, 11],
#         [36, 18, 11]],
#
#        [[38, 18, 13],
#         [39, 19, 14],
#         [38, 19, 14],
#         ...,
#         [36, 18, 11],
#         [36, 18, 11],
#         [36, 18, 11]]], dtype=uint8)
